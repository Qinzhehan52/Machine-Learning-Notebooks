# %% [markdown]
# # 可选实验：Python 和 Jupyter Notebooks 简介
# 欢迎来到第一个可选实验！
# 可选实验旨在：
# - 提供信息 - 就像这本笔记本一样
# - 通过动手示例巩固讲座材料
# - 提供评分实验中使用的例程的工作示例

# %% [markdown]
# ## 目标
# 在这个实验中，你将：
# - 获得 Jupyter notebooks 的简要介绍
# - 参观 Jupyter notebooks
# - 了解 markdown 单元格和代码单元格的区别
# - 练习一些基本的 python

# %% [markdown]
# 熟悉 Jupyter notebooks 最简单的方法是参加“帮助”菜单中提供的游览：

# %% [markdown]
# <figure>
#     <center> <img src="./images/C1W1L1_Tour.png"  alt='missing' width="400"  ><center/>
# <figure/>

# %% [markdown]
# Jupyter notebooks 有两种类型的单元格用于本课程。像这样包含文档的单元格称为 `Markdown 单元格`。该名称源自单元格中使用的简单格式语言。你不需要制作 markdown 单元格。理解下图所示的 `单元格下拉菜单` 很有用。偶尔，单元格会处于错误的模式，你可能需要将其恢复到正确的状态：

# %% [markdown]
# <figure>
#    <img src="./images/C1W1L1_Markdown.png"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# 另一种类型的单元格是 `代码单元格`，你将在其中编写代码：

# %%
#This is  a 'Code' Cell
print("This is  code cell")
# Out:
# This is  code cell

# %% [markdown]
# ## Python
# 你可以在代码单元格中编写代码。
# 要运行代码，请选择单元格并
# - 按住 shift 键并点击 'enter' 或 'return'
# - 点击上方的 'run' 箭头
# <figure>
#     <img src="./images/C1W1L1_Run.png"  width="400"  >
# <figure/>

# %% [markdown]
# ### 打印语句
# 打印语句通常使用 python f-string 风格。
# 尝试在下面的单元格中创建你自己的打印语句。
# 尝试两种运行单元格的方法。

# %%
# print statements
variable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # 恭喜！
# 你现在知道如何在 Jupyter Notebook 中通过了。
