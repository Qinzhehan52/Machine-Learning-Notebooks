# %% [markdown]
# # 可选实验：Python，NumPy 和向量化
# 简要介绍本课程中使用的一些科学计算。特别是 NumPy 科学计算包及其在 python 中的使用。
#
# # 大纲
# - [&nbsp;&nbsp;1.1 目标](#toc_40015_1.1)
# - [&nbsp;&nbsp;1.2 有用的参考资料](#toc_40015_1.2)
# - [2 Python 和 NumPy <a name='Python and NumPy'></a>](#toc_40015_2)
# - [3 向量](#toc_40015_3)
# - [&nbsp;&nbsp;3.1 摘要](#toc_40015_3.1)
# - [&nbsp;&nbsp;3.2 NumPy 数组](#toc_40015_3.2)
# - [&nbsp;&nbsp;3.3 向量创建](#toc_40015_3.3)
# - [&nbsp;&nbsp;3.4 向量操作](#toc_40015_3.4)
# - [4 矩阵](#toc_40015_4)
# - [&nbsp;&nbsp;4.1 摘要](#toc_40015_4.1)
# - [&nbsp;&nbsp;4.2 NumPy 数组](#toc_40015_4.2)
# - [&nbsp;&nbsp;4.3 矩阵创建](#toc_40015_4.3)
# - [&nbsp;&nbsp;4.4 矩阵操作](#toc_40015_4.4)

# %%
import numpy as np    # it is an unofficial standard to use np for numpy
import time

# %% [markdown]
# <a name="toc_40015_1.1"></a>
# ## 1.1 目标
# 在这个实验中，你将：
# - 回顾课程 1 中使用的 NumPy 和 Python 的特性

# %% [markdown]
# <a name="toc_40015_1.2"></a>
# ## 1.2 有用的参考资料
# - NumPy 文档（包括基本介绍）：[NumPy.org](https://NumPy.org/doc/stable/)
# - 一个具有挑战性的特性主题：[NumPy 广播](https://NumPy.org/doc/stable/user/basics.broadcasting.html)

# %% [markdown]
# <a name="toc_40015_2"></a>
# # 2 Python 和 NumPy <a name='Python and NumPy'></a>
# Python 是我们将要在本课程中使用的编程语言。它有一组数字数据类型和算术运算。NumPy 是一个扩展 python 基本功能的库，可以添加更丰富的数据集，包括更多的数字类型、向量、矩阵和许多矩阵函数。NumPy 和 python 几乎可以无缝地协同工作。Python 算术运算符适用于 NumPy 数据类型，许多 NumPy 函数也接受 python 数据类型。

# %% [markdown]
# <a name="toc_40015_3"></a>
# # 3 向量
# <a name="toc_40015_3.1"></a>
# ## 3.1 摘要
# <img align="right" src="./images/C1_W2_Lab04_Vectors.png" style="width:340px;" >在本课程中，你将使用的向量是数字的有序数组。在符号中，向量用小写粗体字母表示，例如 $\mathbf{x}$。向量的元素都是相同的类型。例如，向量不包含字符和数字。数组中的元素数量通常称为 *维度*，尽管数学家可能更喜欢 *秩*。所示向量的维度为 $n$。向量的元素可以用索引引用。在数学设置中，索引通常从 1 到 n。在计算机科学和这些实验中，索引通常从 0 到 n-1。在符号中，当单独引用向量的元素时，会在下标中指示索引，例如，向量 $\mathbf{x}$ 的第 $0$ 个元素是 $x_0$。注意，在这种情况下 x 不是粗体。

# %% [markdown]
# <a name="toc_40015_3.2"></a>
# ## 3.2 NumPy 数组
#
# NumPy 的基本数据结构是一个包含相同类型 (`dtype`) 元素的可索引、n 维 *数组*。马上，你可能会注意到我们重载了术语“维度”。上面，它是向量中的元素数量，这里，维度指的是数组的索引数量。一维或 1-D 数组有一个索引。在课程 1 中，我们将向量表示为 NumPy 1-D 数组。
#
#  - 1-D 数组，形状 (n,): n 个元素，索引从 [0] 到 [n-1]

# %% [markdown]
# <a name="toc_40015_3.3"></a>
# ## 3.3 向量创建

# %% [markdown]
# NumPy 中的数据创建例程通常有一个第一个参数，即对象的形状。这可以是一个 1-D 结果的单个值，也可以是一个指定结果形状的元组 (n,m,...)。下面是使用这些例程创建向量的示例。

# %%
# NumPy routines which allocate memory and fill arrays with value
a = np.zeros(4);                print(f"np.zeros(4) :   a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
a = np.zeros((4,));             print(f"np.zeros(4,) :  a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
a = np.random.random_sample(4); print(f"np.random.random_sample(4): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")

# %% [markdown]
# 有些数据创建例程不接受形状元组：

# %%
# NumPy routines which allocate memory and fill arrays with value but do not accept shape as input argument
a = np.arange(4.);              print(f"np.arange(4.):     a = {a}, a shape = {a.shape}, a data type = {a.dtype}")
a = np.random.rand(4);          print(f"np.random.rand(4): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")

# %% [markdown]
# 也可以手动指定值。

# %%
# NumPy routines which allocate memory and fill with user specified values
a = np.array([5,4,3,2]);  print(f"np.array([5,4,3,2]):  a = {a},     a shape = {a.shape}, a data type = {a.dtype}")
a = np.array([5.,4,3,2]); print(f"np.array([5.,4,3,2]): a = {a}, a shape = {a.shape}, a data type = {a.dtype}")

# %% [markdown]
# 这些都创建了一个包含四个元素的一维向量 `a`。`a.shape` 返回维度。这里我们看到 a.shape = `(4,)` 表示一个包含 4 个元素的 1-d 数组。

# %% [markdown]
# <a name="toc_40015_3.4"></a>
# ## 3.4 向量操作
# 让我们探索一些使用向量的操作。
# <a name="toc_40015_3.4.1"></a>
# ### 3.4.1 索引
# 可以通过索引和切片访问向量的元素。NumPy 提供了一套非常完整的索引和切片功能。我们在这里仅探讨课程所需的基础知识。有关更多详细信息，请参阅 [切片和索引](https://NumPy.org/doc/stable/reference/arrays.indexing.html)。
# **索引** 意味着通过元素在数组中的位置来引用数组中的 *一个元素*。
# **切片** 意味着根据索引从数组中获取元素的 *子集*。
# NumPy 从零开始索引，因此向量 $\mathbf{a}$ 的第 3 个元素是 `a[2]`。

# %%
#vector indexing operations on 1-D vectors
a = np.arange(10)
print(a)

#access an element
print(f"a[2].shape: {a[2].shape} a[2]  = {a[2]}, Accessing an element returns a scalar")

# access the last element, negative indexes count from the end
print(f"a[-1] = {a[-1]}")

#indexs must be within the range of the vector or they will produce and error
try:
    c = a[10]
except Exception as e:
    print("The error message you'll see is:")
    print(e)

# %% [markdown]
# <a name="toc_40015_3.4.2"></a>
# ### 3.4.2 切片
# 切片使用一组三个值 (`start:stop:step`) 创建索引数组。值的子集也是有效的。它的用法最好通过示例来解释：

# %%
#vector slicing operations
a = np.arange(10)
print(f"a         = {a}")

#access 5 consecutive elements (start:stop:step)
c = a[2:7:1];     print("a[2:7:1] = ", c)

# access 3 elements separated by two 
c = a[2:7:2];     print("a[2:7:2] = ", c)

# access all elements index 3 and above
c = a[3:];        print("a[3:]    = ", c)

# access all elements below index 3
c = a[:3];        print("a[:3]    = ", c)

# access all elements
c = a[:];         print("a[:]     = ", c)

# %% [markdown]
# <a name="toc_40015_3.4.3"></a>
# ### 3.4.3 单向量操作
# 有许多涉及单向量操作的有用操作。

# %%
a = np.array([1,2,3,4])
print(f"a             : {a}")
# negate elements of a
b = -a 
print(f"b = -a        : {b}")

# sum all elements of a, returns a scalar
b = np.sum(a) 
print(f"b = np.sum(a) : {b}")

b = np.mean(a)
print(f"b = np.mean(a): {b}")

b = a**2
print(f"b = a**2      : {b}")

# %% [markdown]
# <a name="toc_40015_3.4.4"></a>
# ### 3.4.4 向量-向量逐元素操作
# 大多数 NumPy 算术、逻辑和比较操作也适用于向量。这些运算符逐元素工作。例如
# $$ c_i = a_i + b_i $$

# %%
a = np.array([ 1, 2, 3, 4])
b = np.array([-1,-2, 3, 4])
print(f"Binary operators work element wise: {a + b}")

# %% [markdown]
# 当然，为了使其正常工作，向量必须具有相同的大小：

# %%
#try a mismatched vector operation
c = np.array([1, 2])
try:
    d = a + c
except Exception as e:
    print("The error message you'll see is:")
    print(e)

# %% [markdown]
# <a name="toc_40015_3.4.5"></a>
# ### 3.4.5 标量向量操作
# 向量可以按标量值“缩放”。标量值只是一个数字。标量乘以向量的所有元素。

# %%
a = np.array([1, 2, 3, 4])

# multiply a by a scalar
b = 5 * a 
print(f"b = 5 * a : {b}")

# %% [markdown]
# <a name="toc_40015_3.4.6"></a>
# ### 3.4.6 向量-向量点积
# 点积是线性代数和 NumPy 的支柱。这是本课程中广泛使用的操作，应该被很好地理解。点积如下所示。

# %% [markdown]
# <img src="./images/C1_W2_Lab04_dot_notrans.gif" width=800>

# %% [markdown]
# 点积将两个向量中的值逐元素相乘，然后将结果相加。
# 向量点积要求两个向量的维度相同。

# %% [markdown]
# 让我们在下面实现我们自己的点积版本：
#
# **使用 for 循环**，实现一个返回两个向量点积的函数。给定输入 $a$ 和 $b$，函数返回：
# $$ x = \sum_{i=0}^{n-1} a_i b_i $$
# 假设 `a` 和 `b` 具有相同的形状。

# %%
def my_dot(a, b): 
    """
   Compute the dot product of two vectors
 
    Args:
      a (ndarray (n,)):  input vector 
      b (ndarray (n,)):  input vector with same dimension as a
    
    Returns:
      x (scalar): 
    """
    x=0
    for i in range(a.shape[0]):
        x = x + a[i] * b[i]
    return x

# %%
# test 1-D
a = np.array([1, 2, 3, 4])
b = np.array([-1, 4, 3, 2])
print(f"my_dot(a, b) = {my_dot(a, b)}")

# %% [markdown]
# 注意，点积应该返回一个标量值。
#
# 让我们使用 `np.dot` 尝试相同的操作。

# %%
# test 1-D
a = np.array([1, 2, 3, 4])
b = np.array([-1, 4, 3, 2])
c = np.dot(a, b)
print(f"NumPy 1-D np.dot(a, b) = {c}, np.dot(a, b).shape = {c.shape} ") 
c = np.dot(b, a)
print(f"NumPy 1-D np.dot(b, a) = {c}, np.dot(a, b).shape = {c.shape} ")

# %% [markdown]
# 在上面，你会注意到 1-D 的结果与我们的实现相匹配。

# %% [markdown]
# <a name="toc_40015_3.4.7"></a>
# ### 3.4.7 速度需求：向量与 for 循环
# 我们利用 NumPy 库是因为它提高了速度和内存效率。让我们演示一下：

# %%
np.random.seed(1)
a = np.random.rand(10000000)  # very large arrays
b = np.random.rand(10000000)

tic = time.time()  # capture start time
c = np.dot(a, b)
toc = time.time()  # capture end time

print(f"np.dot(a, b) =  {c:.4f}")
print(f"Vectorized version duration: {1000*(toc-tic):.4f} ms ")

tic = time.time()  # capture start time
c = my_dot(a,b)
toc = time.time()  # capture end time

print(f"my_dot(a, b) =  {c:.4f}")
print(f"loop version duration: {1000*(toc-tic):.4f} ms ")

del(a);del(b)  #remove these big arrays from memory

# %% [markdown]
# 因此，向量化在这个例子中提供了巨大的加速。这是因为 NumPy 更好地利用了底层硬件中可用的数据并行性。GPU 和现代 CPU 实现了单指令多数据 (SIMD) 流水线，允许并行发出多个操作。这在数据集通常非常大的机器学习中至关重要。

# %% [markdown]
# <a name="toc_12345_3.4.8"></a>
# ### 3.4.8 课程 1 中的向量-向量操作
# 向量-向量操作将在课程 1 中频繁出现。原因如下：
# - 展望未来，我们的样本将存储在一个维度为 (m,n) 的数组 `X_train` 中。这将在上下文中进一步解释，但这里重要的是要注意它是一个二维数组或矩阵（参见下一节关于矩阵）。
# - `w` 将是一个形状为 (n,) 的一维向量。
# - 我们将通过循环遍历样本来执行操作，通过索引 X 提取每个样本以单独处理。例如：`X[i]`
# - `X[i]` 返回一个形状为 (n,) 的值，即一维向量。因此，涉及 `X[i]` 的操作通常是向量-向量操作。
#
# 这是一个有点冗长的解释，但在执行向量操作时，对齐和理解操作数的形状非常重要。

# %%
# show common Course 1 example
X = np.array([[1],[2],[3],[4]])
w = np.array([2])
c = np.dot(X[1], w)

print(f"X[1] has shape {X[1].shape}")
print(f"w has shape {w.shape}")
print(f"c has shape {c.shape}")

# %% [markdown]
# <a name="toc_40015_4"></a>
# # 4 矩阵

# %% [markdown]
# <a name="toc_40015_4.1"></a>
# ## 4.1 摘要
# 矩阵是二维数组。矩阵的元素都是相同类型的。在符号中，矩阵用大写粗体字母表示，例如 $\mathbf{X}$。在这个和其他实验中，`m` 通常是行数，`n` 是列数。矩阵的元素可以用二维索引引用。在数学设置中，索引中的数字通常从 1 到 n。在计算机科学和这些实验中，索引将从 0 到 n-1。
# <figure>
#     <center> <img src="./images/C1_W2_Lab04_Matrices.png"  alt='missing'  width=900><center/>
#     <figcaption> 通用矩阵符号，第一个索引是行，第二个索引是列 </figcaption>
# <figure/>

# %% [markdown]
# <a name="toc_40015_4.2"></a>
# ## 4.2 NumPy 数组
#
# NumPy 的基本数据结构是一个包含相同类型 (`dtype`) 元素的可索引、n 维 *数组*。这些在前面已经描述过。矩阵具有二维 (2-D) 索引 [m,n]。
#
# 在课程 1 中，2-D 矩阵用于保存训练数据。训练数据是 $m$ 个样本乘 $n$ 个特征，创建一个 (m,n) 数组。课程 1 不直接对矩阵进行操作，而是通常将样本提取为向量并对其进行操作。下面你将回顾：
# - 数据创建
# - 切片和索引

# %% [markdown]
# <a name="toc_40015_4.3"></a>
# ## 4.3 矩阵创建
# 创建 1-D 向量的相同函数将创建 2-D 或 n-D 数组。这里有一些例子

# %% [markdown]
# 下面，提供形状元组以实现 2-D 结果。注意 NumPy 如何使用括号来表示每个维度。进一步注意，NumPy 在打印时每行打印一行。

# %%
a = np.zeros((1, 5))                                       
print(f"a shape = {a.shape}, a = {a}")                     

a = np.zeros((2, 1))                                                                   
print(f"a shape = {a.shape}, a = {a}") 

a = np.random.random_sample((1, 1))  
print(f"a shape = {a.shape}, a = {a}")

# %% [markdown]
# 也可以手动指定数据。维度由与上面打印格式匹配的额外括号指定。

# %%
# NumPy routines which allocate memory and fill with user specified values
a = np.array([[5], [4], [3]]);   print(f" a shape = {a.shape}, np.array: a = {a}")
a = np.array([[5],   # One can also
              [4],   # separate values
              [3]]); #into separate rows
print(f" a shape = {a.shape}, np.array: a = {a}")

# %% [markdown]
# <a name="toc_40015_4.4"></a>
# ## 4.4 矩阵操作
# 让我们探索一些使用矩阵的操作。

# %% [markdown]
# <a name="toc_40015_4.4.1"></a>
# ### 4.4.1 索引

# %% [markdown]
# 矩阵包含第二个索引。这两个索引描述 [行, 列]。访问可以返回一个元素或一行/列。见下文：

# %%
#vector indexing operations on matrices
a = np.arange(6).reshape(-1, 2)   #reshape is a convenient way to create matrices
print(f"a.shape: {a.shape}, \na= {a}")

#access an element
print(f"\na[2,0].shape:   {a[2, 0].shape}, a[2,0] = {a[2, 0]},     type(a[2,0]) = {type(a[2, 0])} Accessing an element returns a scalar\n")

#access a row
print(f"a[2].shape:   {a[2].shape}, a[2]   = {a[2]}, type(a[2])   = {type(a[2])}")

# %% [markdown]
# 值得注意最后一个例子。仅通过指定行访问矩阵将返回一个 *1-D 向量*。

# %% [markdown]
# **重塑 (Reshape)**
# 前面的例子使用 [reshape](https://numpy.org/doc/stable/reference/generated/numpy.reshape.html) 来塑造数组。
# `a = np.arange(6).reshape(-1, 2) `
# 这行代码首先创建了一个包含六个元素的 *1-D 向量*。然后它使用 reshape 命令将该向量重塑为 *2-D* 数组。这也可以写成：
# `a = np.arange(6).reshape(3, 2) `
# 以得到相同的 3 行 2 列数组。
# -1 参数告诉例程根据数组的大小和列数计算行数。

# %% [markdown]
# <a name="toc_40015_4.4.2"></a>
# ### 4.4.2 切片
# 切片使用一组三个值 (`start:stop:step`) 创建索引数组。值的子集也是有效的。它的用法最好通过示例来解释：

# %%
#vector 2-D slicing operations
a = np.arange(20).reshape(-1, 10)
print(f"a = \n{a}")

#access 5 consecutive elements (start:stop:step)
print("a[0, 2:7:1] = ", a[0, 2:7:1], ",  a[0, 2:7:1].shape =", a[0, 2:7:1].shape, "a 1-D array")

#access 5 consecutive elements (start:stop:step) in two rows
print("a[:, 2:7:1] = \n", a[:, 2:7:1], ",  a[:, 2:7:1].shape =", a[:, 2:7:1].shape, "a 2-D array")

# access all elements
print("a[:,:] = \n", a[:,:], ",  a[:,:].shape =", a[:,:].shape)

# access all elements in one row (very common usage)
print("a[1,:] = ", a[1,:], ",  a[1,:].shape =", a[1,:].shape, "a 1-D array")
# same as
print("a[1]   = ", a[1],   ",  a[1].shape   =", a[1].shape, "a 1-D array")

# %% [markdown]
# <a name="toc_40015_5.0"></a>
# ## 恭喜！
# 在这个实验中，你掌握了课程 1 所需的 Python 和 NumPy 特性。
