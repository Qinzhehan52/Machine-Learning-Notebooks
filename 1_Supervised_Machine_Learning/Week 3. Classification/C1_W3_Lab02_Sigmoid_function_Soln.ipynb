# %% [markdown]
# # 可选实验：逻辑回归
#
# 在这个不评分的实验中，你将
# - 探索 Sigmoid 函数（也称为逻辑函数）
# - 探索使用 Sigmoid 函数的逻辑回归

# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from plt_one_addpt_onclick import plt_one_addpt_onclick
from lab_utils_common import draw_vthresh
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# ## Sigmoid 或逻辑函数
# <img align="left" src="./images/C1_W3_LogisticRegression_left.png"     style=" width:300px; padding: 10px; " >正如讲座视频中所讨论的，对于分类任务，我们可以通过使用我们的线性回归模型 $f_{\mathbf{w},b}(\mathbf{x}^{(i)}) = \mathbf{w} \cdot  \mathbf{x}^{(i)} + b$ 来开始，在给定 $x$ 的情况下预测 $y$。
# - 然而，我们希望我们的分类模型的预测在 0 和 1 之间，因为我们的输出变量 $y$ 要么是 0，要么是 1。
# - 这可以通过使用“Sigmoid 函数”来实现，该函数将所有输入值映射到 0 和 1 之间的值。
#
#
# 让我们实现 Sigmoid 函数并亲自看看。
#
# ## Sigmoid 函数公式
#
# Sigmoid 函数的公式如下 -
#
# $g(z) = \frac{1}{1+e^{-z}}\tag{1}$
#
# 在逻辑回归的情况下，z（Sigmoid 函数的输入）是线性回归模型的输出。
# - 在单个示例的情况下，$z$ 是标量。
# - 在多个示例的情况下，$z$ 可以是包含 $m$ 个值的向量，每个示例一个值。
# - Sigmoid 函数的实现应涵盖这两种潜在的输入格式。
# 让我们在 Python 中实现这一点。

# %% [markdown]
# NumPy 有一个名为 [`exp()`](https://numpy.org/doc/stable/reference/generated/numpy.exp.html) 的函数，它提供了一种计算输入数组 (`z`) 中所有元素的指数 ($e^{z}$) 的便捷方法。
#
# 它也适用于单个数字作为输入，如下所示。

# %%
# Input is an array. 
input_array = np.array([1,2,3])
exp_array = np.exp(input_array)

print("Input to exp:", input_array)
print("Output of exp:", exp_array)

# Input is a single number
input_val = 1  
exp_val = np.exp(input_val)

print("Input to exp:", input_val)
print("Output of exp:", exp_val)

# %% [markdown]
# `sigmoid` 函数在 Python 中的实现如下面的单元格所示。

# %%
def sigmoid(z):
    """
    Compute the sigmoid of z

    Args:
        z (ndarray): A scalar, numpy array of any size.

    Returns:
        g (ndarray): sigmoid(z), with the same shape as z
         
    """

    g = 1/(1+np.exp(-z))
   
    return g

# %% [markdown]
# 让我们看看对于不同的 `z` 值，这个函数的输出是什么

# %%
# Generate an array of evenly spaced values between -10 and 10
z_tmp = np.arange(-10,11)

# Use the function implemented above to get the sigmoid values
y = sigmoid(z_tmp)

# Code for pretty printing the two arrays next to each other
np.set_printoptions(precision=3) 
print("Input (z), Output (sigmoid(z))")
print(np.c_[z_tmp, y])

# %% [markdown]
# 左列的值是 `z`，右列的值是 `sigmoid(z)`。如你所见，Sigmoid 的输入值范围从 -10 到 10，输出值范围从 0 到 1。
#
# 现在，让我们尝试使用 `matplotlib` 库绘制此函数。

# %%
# Plot z vs sigmoid(z)
fig,ax = plt.subplots(1,1,figsize=(5,3))
ax.plot(z_tmp, y, c="b")

ax.set_title("Sigmoid function")
ax.set_ylabel('sigmoid(z)')
ax.set_xlabel('z')
draw_vthresh(ax,0)

# %% [markdown]
# 如你所见，当 `z` 变为大的负值时，Sigmoid 函数接近 `0`，当 `z` 变为大的正值时，它接近 `1`。

# %% [markdown]
# ## 逻辑回归
# <img align="left" src="./images/C1_W3_LogisticRegression_right.png"     style=" width:300px; padding: 10px; " > 逻辑回归模型将 Sigmoid 应用于我们熟悉的线性回归模型，如下所示：
#
# $$ f_{\mathbf{w},b}(\mathbf{x}^{(i)}) = g(\mathbf{w} \cdot \mathbf{x}^{(i)} + b ) \tag{2} $$
#
#   其中
#
#   $g(z) = \frac{1}{1+e^{-z}}\tag{3}$

# %% [markdown]
#
# 让我们将逻辑回归应用于肿瘤分类的分类数据示例。
# 首先，加载示例和参数的初始值。

# %%
x_train = np.array([0., 1, 2, 3, 4, 5])
y_train = np.array([0,  0, 0, 1, 1, 1])

w_in = np.zeros((1))
b_in = 0

# %% [markdown]
# 尝试以下步骤：
# - 点击“运行逻辑回归”以找到给定训练数据的最佳逻辑回归模型
#     - 注意生成的模型非常适合数据。
#     - 注意，橙色线是上面的 '$z$' 或 $\mathbf{w} \cdot \mathbf{x}^{(i)} + b$。它与线性回归模型中的线不匹配。
# 通过应用*阈值*进一步改善这些结果。
# - 勾选“切换 0.5 阈值”框以显示应用阈值后的预测。
#     - 这些预测看起来不错。预测与数据匹配
#     - 现在，在最大的肿瘤尺寸范围（接近 10）中添加更多数据点，并重新运行逻辑回归。
#     - 与线性回归模型不同，该模型继续做出正确的预测

# %%
plt.close('all') 
addpt = plt_one_addpt_onclick( x_train,y_train, w_in, b_in, logistic=True)

# %% [markdown]
# ## 祝贺！
# 你已经探索了 Sigmoid 函数在逻辑回归中的使用。
