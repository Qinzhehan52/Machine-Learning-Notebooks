# %% [markdown]
# # Ungraded Lab:  Logistic Regression using Scikit-Learn

# %% [markdown]
# ## 目标
# 在这个实验中，你将：
# -  使用 scikit-learn 训练逻辑回归模型。

# %% [markdown]
# ## 数据集
# 让我们从之前相同的数据集开始。

# %%
import numpy as np

X = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])
y = np.array([0, 0, 0, 1, 1, 1])

# %% [markdown]
# ## 拟合模型
#
# 下面的代码从 scikit-learn 导入 [逻辑回归模型](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression)。你可以通过调用 `fit` 函数在训练数据上拟合此模型。

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression()
lr_model.fit(X, y)

# %% [markdown]
# ## 进行预测
#
# 你可以通过调用 `predict` 函数查看此模型所做的预测。

# %%
y_pred = lr_model.predict(X)

print("Prediction on training set:", y_pred)

# %% [markdown]
# ## 计算准确率
#
# 你可以通过调用 `score` 函数来计算此模型的准确率。

# %%
print("Accuracy on training set:", lr_model.score(X, y))
