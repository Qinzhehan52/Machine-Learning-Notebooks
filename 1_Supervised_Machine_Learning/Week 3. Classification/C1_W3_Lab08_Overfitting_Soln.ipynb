# %% [markdown]
# # 不评分实验：过拟合
#
# <img align="left" src="./images/C1_W3_Overfitting_a.png"     style=" width:250px; padding: 10px; " >
# <img align="left" src="./images/C1_W3_Overfitting_b.png"     style=" width:250px; padding: 10px; " >
# <img align="left" src="./images/C1_W3_Overfitting_c.png"     style=" width:250px; padding: 10px; " >

# %% [markdown]
# ## 目标
# 在这个实验中，你将探索：
# - 可能发生过拟合的情况
# - 一些解决方案

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from ipywidgets import Output
from plt_overfit import overfit_example, output
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# # 过拟合
# 本周的讲座描述了可能出现过拟合的情况。运行下面的单元格以生成一个允许你探索过拟合的图表。单元格下方有更多说明。

# %%
plt.close("all")
display(output)
ofit = overfit_example(False)

# %% [markdown]
# 在上面的图中，你可以：
# - 在回归和分类示例之间切换
# - 添加数据
# - 选择模型的次数
# - 将模型拟合到数据
#
# 这里有一些你应该尝试的事情：
# - 用次数 = 1 拟合数据；注意“欠拟合”。
# - 用次数 = 6 拟合数据；注意“过拟合”
# - 调整次数以获得“最佳拟合”
# - 添加数据：
#     - 极端示例可能会增加过拟合（假设它们是异常值）。
#     - 名义示例可以减少过拟合
# - 在 `回归` 和 `分类` 之间切换以尝试这两个示例。
#
# 要重置图表，请重新运行该单元格。请缓慢点击，以便在接收下一次点击之前让图表更新。
#
# 关于实现的说明：
# - “理想”曲线代表生成器模型，向其中添加了噪声以获得数据集
# - “拟合”不使用纯梯度下降来提高速度。这些方法可用于较小的数据集。

# %% [markdown]
# ## 祝贺！
# 你已经对过拟合的原因和解决方案产生了一些直觉。在下一个实验中，你将探索一种常用的解决方案，正则化。
